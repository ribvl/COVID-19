# %% [markdown]
# # Comparação de dados - [covid.saude.gov.br](https://covid.saude.gov.br/) e [brasil.io](https://brasil.io/dataset/covid19)
#
# O Ministério da Saúde retirou, no dia 05/06/2020, os dados do portal [covid.saude.gov.br](https://covid.saude.gov.br/) e retomou a disponibilização no dia 10/06/2020
#
# Alternativamente, o site [brasil.io](https://brasil.io/dataset/covid19) tem mantido um conjunto de dados disponibilidades pelas Secretarias de Saúde estaduais. Esse notebook compara os dois conjuntos de dados e mostra a evolução do COVID-19 em alguns estados e municípios.

# %%
from datetime import date
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns
from ipywidgets import interact

# %matplotlib inline
sns.set_style('whitegrid')

pd.set_option('display.max_rows', 150)
# pd.set_option('plotting.backend', 'matplotlib')
pd.options.plotting.backend = "plotly"
pd.options.plotting.backend = "matplotlib"

# %%
print("Última atualização do notebook: {}".format(date.today().strftime('%m/%d/%y')))
# Out:
# Última atualização do notebook: 11/09/20

# %% [markdown]
# # Dados [covid.saude.gov.br](https://covid.saude.gov.br)

# %% [markdown]
# ## Dados dos dias 06/02/2020 e 06/17/2020

# %%
dados_0602 = pd.read_excel('Data\HIST_PAINEL_COVIDBR_2020-06-02.xlsx')

# %%
dados_novos = pd.read_excel('Data\HIST_PAINEL_COVIDBR_2020-06-17.xlsx')

# %% [markdown]
# ## Funções de tratamento de colunas e criação de novos dataframes específicos para estados, municípios e regiões

# %%
def contador_dias(dataframe, groupby_list):
    dataframe['contadorDiasCasos'] = dataframe.sort_values(by=['datetime']).groupby(groupby_list)['casosAcumulado'].cumcount() + 1
    dataframe['contadorObitosCasos'] = dataframe[dataframe['obitosAcumulado'] > 0].sort_values(by=['datetime']).groupby(groupby_list)['obitosAcumulado'].cumcount() + 1
    dataframe['contadorObitosCasos'].fillna(0, inplace=True)
    dataframe['contadorObitosCasos'] = dataframe['contadorObitosCasos'].astype(int)

# contador_dias(dados_estados, ['estado'])
# contador_dias(dados_regiao, ['regiao'])
# contador_dias(dados_municipios, ['municipioEstado'])

# %%
def column_treatment(df):
    df['datetime'] = pd.to_datetime(df['data'], format='%Y-%m-%d')
    df[['coduf','codmun','codRegiaoSaude']] = df[['coduf', 'codmun', 'codRegiaoSaude']].astype('category')
    df.dropna(subset=['populacaoTCU2019'], inplace=True)
    if df['populacaoTCU2019'].dtype == 'O':
        df['populacaoTCU2019'] = df['populacaoTCU2019'].apply(lambda i: re.sub(r"\(..?\)", "", i) if r"(" in i else i)
        df['populacaoTCU2019'] = df['populacaoTCU2019'].str.replace('.','')
        df['populacaoTCU2019'] = df['populacaoTCU2019'].astype('int')
    df[['Recuperadosnovos', 'emAcompanhamentoNovos']] = df[['Recuperadosnovos', 'emAcompanhamentoNovos']].fillna(0)
    df[['Recuperadosnovos', 'emAcompanhamentoNovos']] = df[['Recuperadosnovos', 'emAcompanhamentoNovos']].astype('int')
    df['casosNormalizado_100mil_habit'] = df['casosAcumulado'] / (df['populacaoTCU2019'] / 100000)
    df['obitosNormalizado_100mil_habit'] = df['obitosAcumulado'] / (df['populacaoTCU2019'] / 100000)
    df['casosNormalizado_1milhao_habit'] = df['casosAcumulado'] / (df['populacaoTCU2019'] / 1000000)
    df['obitosNormalizado_1milhao_habit'] = df['obitosAcumulado'] / (df['populacaoTCU2019'] / 1000000)
    df['tipoTerritorio'] = np.where(df['municipio'].notna(), "municipio", 
                                                  (np.where(
                                                      (df['estado'].notna()) & (df['regiao']!='Brasil'), 
                                                      "estado", "pais")))
    df['municipioEstado'] = np.where(df['municipio'].notna(), df['municipio']+'-'+df['estado'], np.nan)
    
    df_pais = df[df['tipoTerritorio'] == 'pais'].copy()
    df_estado = df[df['tipoTerritorio'] == 'estado'].copy()
    df_municipio = df[df['tipoTerritorio'] == 'municipio'].copy()
    contador_dias(df_pais, ['regiao'])
    contador_dias(df_estado, ['estado'])
    contador_dias(df_municipio, ['municipioEstado'])
    df = pd.concat([df_pais, df_estado, df_municipio], ignore_index=True)
    
    df.drop(['data'], axis=1, inplace=True)
    df = df[['regiao', 'estado', 'municipio', 'municipioEstado', 'tipoTerritorio', 'datetime',
             'coduf', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude', 'semanaEpi', 'populacaoTCU2019',
             'casosAcumulado', 'obitosAcumulado', 'casosNovos', 'obitosNovos', 'contadorDiasCasos', 'contadorObitosCasos', 
             'casosNormalizado_100mil_habit', 'obitosNormalizado_100mil_habit', 'casosNormalizado_1milhao_habit', 'obitosNormalizado_1milhao_habit',
             'Recuperadosnovos', 'emAcompanhamentoNovos']]
    
    return df

# %%
# def rolling_average():
#     dados_municipios['rolling_avg_7d_casosAcumulado'] = dados_municipios.sort_values(by=['datetime'])\
#                                                                     .groupby(['municipioEstado'])\
#                                                                     .rolling(7)['casosAcumulado']\
#                                                                     .mean().reset_index(0,drop=True)

#     dados_municipios['rolling_avg_7d_casosNormalizado'] = dados_municipios.sort_values(by=['datetime'])\
#                                                                     .groupby(['municipioEstado'])\
#                                                                     .rolling(7)['casosNormalizado']\
#                                                                     .mean().reset_index(0,drop=True)

# dados_municipios.sort_values(by=['datetime']).groupby(['municipioEstado']).rolling(7)['casosAcumulado'].mean()
# dados_municipios.sort_values(by=['datetime']).groupby(['municipioEstado']).rolling(7)['casosAcumulado'].mean().reset_index(0,drop=True)

# %%
dados_0602 = column_treatment(dados_0602)
dados_novos = column_treatment(dados_novos)

# %%
def caracteristicas_plot(bbox_anchor_x, bbox_anchor_y, labels_fontsize, legend_bool,
                        xaxis_datetime_bool, xaxis_title_string, yaxis_title_string):
    '''
    Função com os ajustes de características do plot, i.e tamanho das fontes de títulos e labels
    '''
    
    # Posiciona caixa de legendas para fora do gráfico, ao lado direito, se o usuário escolher ter legenda
    if legend_bool == True:
        plt.gcf().legend(bbox_to_anchor=(bbox_anchor_x, bbox_anchor_y), prop={'size': labels_fontsize-2})

    # Formata ticks do eixo x como datas, se o usuário escolher usar datas no eixo x
    if xaxis_datetime_bool == True:
        # formato da data do eixo para dia-mês e localização dos ticks no eixo
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m')) # '%d-%m' dia-mês; %U or %W Week number of the year
        plt.gca().xaxis.set_major_locator(mdates.DayLocator()) #mdates.DayLocator(); mdates.MonthLocator() determina a posição do tick quando se plota datas
        
        # rotaciona as labels do eixo x
        plt.gcf().autofmt_xdate()
              
    # nome do título do eixo
    plt.gca().set_xlabel(xaxis_title_string)
    plt.gca().set_ylabel(yaxis_title_string)
    
    # formata número (i.e. 10^4 para 10000 - %d=integer)
    plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%d'))

    # tamanho da fonte das labels/títulos do eixo
    plt.gca().title.set_fontsize(labels_fontsize) 
    plt.gca().xaxis.label.set_fontsize(labels_fontsize) 
    plt.gca().yaxis.label.set_fontsize(labels_fontsize)

    # tamanho da fonte dos 'ticks' (dados/números/datas) do eixo
    # list comprehension para cada item/dados/número/dado do eixo
    [tick.label.set_fontsize(labels_fontsize) for tick in plt.gca().xaxis.get_major_ticks()]
    [tick.label.set_fontsize(labels_fontsize) for tick in plt.gca().yaxis.get_major_ticks()]
    
    plt.tight_layout()

# %%
# fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)
def plot_data_completo(dataframe, column_string, rows_list, groupby_list, column_list, 
                       title_string, legend_bool, logy_bool, figsize_x, figsize_y, 
                       bbox_anchor_x, bbox_anchor_y, labels_fontsize,
                       xaxis_datetime_bool, xaxis_title_string, yaxis_title_string, axes):
    dataframe.loc[dataframe[column_string].isin(rows_list)]\
        .groupby(groupby_list)[column_list]\
        .sum()\
        .unstack()\
        .plot(figsize=(figsize_x, figsize_y), legend=False, logy=logy_bool, title=title_string, ax=axes)
    
    caracteristicas_plot(bbox_anchor_x, bbox_anchor_y, labels_fontsize, legend_bool,
                        xaxis_datetime_bool, xaxis_title_string, yaxis_title_string)

# %% [markdown]
# ## Funções de plot

# %% [markdown]
# ## Análise dos dados

# %%
dados_0602.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146270 entries, 0 to 146269
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   regiao                           146270 non-null  object
#  1   estado                           146172 non-null  object
#  2   municipio                        143979 non-null  object
#  3   municipioEstado                  143979 non-null  object
#  4   tipoTerritorio                   146270 non-null  object
#  5   datetime                         146270 non-null  datetime64[ns]
#  6   coduf                            146270 non-null  category
#  7   codmun                           143979 non-null  category
#  8   codRegiaoSaude                   143979 non-null  category
#  9   nomeRegiaoSaude                  143979 non-null  object
#  10  semanaEpi                        146270 non-null  int64
#  11  populacaoTCU2019                 146270 non-null  int32
#  12  casosAcumulado                   146270 non-null  int64
#  13  obitosAcumulado                  146270 non-null  int64
#  14  casosNovos                       146270 non-null  int64
#  15  obitosNovos                      146270 non-null  int64
#  16  contadorDiasCasos                146270 non-null  int64
#  17  contadorObitosCasos              146270 non-null  int32
#  18  casosNormalizado_100mil_habit    146270 non-null  float64
#  19  obitosNormalizado_100mil_habit   146270 non-null  float64
#  20  casosNormalizado_1milhao_habit   146270 non-null  float64
#  21  obitosNormalizado_1milhao_habit  146270 non-null  float64
#  22  Recuperadosnovos                 146270 non-null  int32
#  23  emAcompanhamentoNovos            146270 non-null  int32
# dtypes: category(3), datetime64[ns](1), float64(4), int32(4), int64(6), object(6)
# memory usage: 22.1+ MB

# %%
municipios_plot = ['Rio de Janeiro-RJ']
groupby_var = ['contadorDiasCasos', 'municipioEstado']
xaxis_datetime_bool = False

fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

plot_data_completo(dataframe = dados_0602, column_string = 'municipioEstado', 
            rows_list = municipios_plot, 
            groupby_list = groupby_var,
            column_list = ['casosNormalizado_1milhao_habit'], 
            title_string = "Casos - Municípios", 
            legend_bool = True, logy_bool = True, figsize_x = 10, figsize_y = 7, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 18,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

plot_data_completo(dataframe = dados_novos, column_string = 'municipioEstado', 
            rows_list = municipios_plot, 
            groupby_list = groupby_var,
            column_list = ['casosNormalizado_1milhao_habit'], 
            title_string = "Casos - Municípios", 
            legend_bool = True, logy_bool = True, figsize_x = 10, figsize_y = 7, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 18,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

# %%
estados_plot = ['RJ','SP','MG','ES']
groupby_var = ['datetime', 'estado']
xaxis_datetime_bool = True

fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

plot_data_completo(dataframe = dados_0602, column_string = 'estado', 
            rows_list = estados_plot, 
            groupby_list = groupby_var,
            column_list = ['casosNormalizado_1milhao_habit'], 
            title_string = "Casos - Estados", 
            legend_bool = True, logy_bool = True, figsize_x = 35, figsize_y = 15, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 18,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

plot_data_completo(dataframe = dados_novos, column_string = 'estado', 
            rows_list = estados_plot, 
            groupby_list = groupby_var,
            column_list = ['casosNormalizado_1milhao_habit'], 
            title_string = "Casos - Estados", 
            legend_bool = True, logy_bool = True, figsize_x = 35, figsize_y =15, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 18,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

# %% [markdown]
# ### Comparativo dados [covid.saude.gov.br](https://covid.saude.gov.br)

# %%
def merge_compare(df_old, df_new, tipoTerritorio, col_new_merge, merge_on, col_drop, suffixes):
    comp_gov = pd.merge(df_old[df_old['tipoTerritorio'] == tipoTerritorio], 
                        df_new[col_new_merge][df_new['tipoTerritorio'] == tipoTerritorio], 
                        how='left', left_on=merge_on, right_on=merge_on, suffixes=suffixes)

    comp_gov.drop(col_drop, inplace=True, axis=1)
    comp_gov = comp_gov.sort_values(by=['datetime', 'municipioEstado'])
    # comp_gov = comp_gov[rearrange_order]
    return comp_gov

def diferenca_dados(df, suffixes, coluna_comparacao):
    (col_old_suffix, col_new_suffix) = suffixes
    new_cols = []
    for col in coluna_comparacao:
        df[col+'_dif'] = (df[col+col_old_suffix] - df[col+col_new_suffix]).abs()
        new_cols.append(col+'_dif')
    
    return new_cols

# %%
tipoTerritorio = 'municipio'
col_new_merge = ['datetime', 'municipioEstado', 'casosAcumulado','casosNovos', 'obitosAcumulado', 'obitosNovos','Recuperadosnovos', 'emAcompanhamentoNovos']
merge_on = ['datetime', 'municipioEstado']
col_drop = ['regiao', 'municipio', 'semanaEpi', 'populacaoTCU2019','casosNormalizado_100mil_habit', 'obitosNormalizado_100mil_habit','casosNormalizado_1milhao_habit', 'obitosNormalizado_1milhao_habit','contadorDiasCasos', 'contadorObitosCasos']
suffixes = ('_06-02', '_novos')
# rearrange_order = ['estado', 'municipioEstado', 'datetime','casosAcumulado_06-02', 'casosAcumulado_novos','casosNovos_06-02', 'casosNovos_novos','obitosAcumulado_06-02', 'obitosAcumulado_novos', 'obitosNovos_06-02', 'obitosNovos_novos','Recuperadosnovos_06-02', 'Recuperadosnovos_novos', 'emAcompanhamentoNovos_06-02', 'emAcompanhamentoNovos_novos']
comp_gov = merge_compare(dados_0602, dados_novos, tipoTerritorio, col_new_merge, merge_on, col_drop, suffixes)

coluna_comparacao = ['casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos', 'Recuperadosnovos', 'emAcompanhamentoNovos']
new_cols = diferenca_dados(comp_gov, suffixes, coluna_comparacao) 

comp_gov[new_cols] = comp_gov[new_cols].replace({0: np.nan})
# print(comp_gov.columns)
print(comp_gov.shape)
comp_gov_diff = comp_gov[new_cols].dropna(thresh=1, axis=0)
comp_gov_diff.notna().sum()
# Out:
# (143979, 26)
# casosAcumulado_dif              0
# casosNovos_dif               6551
# obitosAcumulado_dif            11
# obitosNovos_dif               595
# Recuperadosnovos_dif            0
# emAcompanhamentoNovos_dif       0
# dtype: int64

# %%
comp_gov.columns
# Out:
# Index(['estado', 'municipioEstado', 'tipoTerritorio', 'datetime', 'coduf',
#        'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude', 'casosAcumulado_06-02',
#        'obitosAcumulado_06-02', 'casosNovos_06-02', 'obitosNovos_06-02',
#        'Recuperadosnovos_06-02', 'emAcompanhamentoNovos_06-02',
#        'casosAcumulado_novos', 'casosNovos_novos', 'obitosAcumulado_novos',
#        'obitosNovos_novos', 'Recuperadosnovos_novos',
#        'emAcompanhamentoNovos_novos', 'casosAcumulado_dif', 'casosNovos_dif',
#        'obitosAcumulado_dif', 'obitosNovos_dif', 'Recuperadosnovos_dif',
#        'emAcompanhamentoNovos_dif'],
#       dtype='object')

# %%
col_comparar = 'casosNovos'

conditions = (comp_gov[col_comparar+'_dif'].notna()) & (comp_gov[col_comparar+'_novos'] < 0)
comp_gov[conditions][['estado', 'municipioEstado', 'datetime', col_comparar+suffixes[0],col_comparar+suffixes[1], col_comparar+'_dif']].head()
# Out:
#        estado          municipioEstado   datetime  casosNovos_06-02  \
# 129905     RS               Lajeado-RS 2020-03-30                 0
# 51504      AL                Maceió-AL 2020-03-30                 0
# 140087     GO  Aparecida de Goiânia-GO 2020-03-31                 0
# 33867      RN                 Caicó-RN 2020-03-31                 0
# 39070      PB        Campina Grande-PB 2020-03-31                 0
#
#         casosNovos_novos  casosNovos_dif
# 129905                -1             1.0
# 51504                 -4             4.0
# 140087                -1             1.0
# 33867                 -1             1.0
# 39070                 -1             1.0

# %%
col_comparar = 'obitosAcumulado'

conditions = (comp_gov[col_comparar+'_dif'].notna()) & (comp_gov[col_comparar+'_novos'] != 0)
comp_gov[conditions][['estado', 'municipioEstado', 'datetime', col_comparar+suffixes[0],col_comparar+suffixes[1], col_comparar+'_dif']].head()
# Out:
#      estado municipioEstado   datetime  obitosAcumulado_06-02  \
# 4962     RR  Alto Alegre-RR 2020-05-26                      1
# 4906     RR      Amajari-RR 2020-05-26                      1
# 5029     RR    Boa Vista-RR 2020-05-26                    611
# 5096     RR       Bonfim-RR 2020-05-26                      8
# 5157     RR        Cantá-RR 2020-05-26                      7
#
#       obitosAcumulado_novos  obitosAcumulado_dif
# 4962                      3                  2.0
# 4906                      2                  1.0
# 5029                     83                528.0
# 5096                      2                  6.0
# 5157                      2                  5.0

# %%
selected_cols = ['municipioEstado', 'datetime']
selected_cols.extend([col for col in comp_gov.columns for word in ['casosNovos', 'casosAcumulado', 'obitosNovos', 'obitosAcumulado'] if word in col])

comp_gov[comp_gov['casosNovos_dif'] > 100][selected_cols]
# Out:
#               municipioEstado   datetime  casosAcumulado_06-02  \
# 66296       Belo Horizonte-MG 2020-03-28                   129
# 143912            Brasília-DF 2020-03-28                   260
# 27535            Fortaleza-CE 2020-03-28                   304
# 3695                Manaus-AM 2020-03-28                   105
# 131628        Porto Alegre-RS 2020-03-28                   107
# 85791       Rio de Janeiro-RJ 2020-03-28                   489
# 105125           São Paulo-SP 2020-03-28                  1149
# 119056       Florianópolis-SC 2020-05-25                   500
# 84706              Niterói-RJ 2020-05-26                  1692
# 119059       Florianópolis-SC 2020-05-28                   514
# 86235   São João de Meriti-RJ 2020-06-02                   769
#
#         obitosAcumulado_06-02  casosNovos_06-02  obitosNovos_06-02  \
# 66296                       0                 0                  0
# 143912                      0                 0                  0
# 27535                       4                 0                  0
# 3695                        0                 0                  0
# 131628                      2                 0                  0
# 85791                       9                 0                  0
# 105125                     76                 0                  0
# 119056                      6                 0                  0
# 84706                      92                 0                  3
# 119059                      6                 0                  0
# 86235                      94                 0                  4
#
#         casosAcumulado_novos  casosNovos_novos  obitosAcumulado_novos  \
# 66296                    129               129                      0
# 143912                   260               260                      0
# 27535                    304               304                      4
# 3695                     105               105                      0
# 131628                   107               107                      2
# 85791                    489               489                      9
# 105125                  1149              1149                     76
# 119056                   500              -144                      6
# 84706                   1692              -349                     92
# 119059                   514              -114                      6
# 86235                    769              -115                     94
#
#         obitosNovos_novos  casosAcumulado_dif  casosNovos_dif  \
# 66296                   0                 NaN           129.0
# 143912                  0                 NaN           260.0
# 27535                   4                 NaN           304.0
# 3695                    0                 NaN           105.0
# 131628                  2                 NaN           107.0
# 85791                   9                 NaN           489.0
# 105125                 76                 NaN          1149.0
# 119056                 -1                 NaN           144.0
# 84706                   3                 NaN           349.0
# 119059                 -1                 NaN           114.0
# 86235                   4                 NaN           115.0
#
#         obitosAcumulado_dif  obitosNovos_dif
# 66296                   NaN              NaN
# 143912                  NaN              NaN
# 27535                   NaN              4.0
# 3695                    NaN              NaN
# 131628                  NaN              2.0
# 85791                   NaN              9.0
# 105125                  NaN             76.0
# 119056                  NaN              1.0
# 84706                   NaN              NaN
# 119059                  NaN              1.0
# 86235                   NaN              NaN

# %% [markdown]
# # Dados [brasil.io](https://brasil.io/dataset/covid19)

# %%
dados_br_io = pd.read_csv(r'DATA\brasil.io-covid19-caso_full-2020-06-18-00.22.10.csv')
dados_br_io['date'] = pd.to_datetime(dados_br_io['date'], format='%Y-%m-%d')

br_io_col_names = ['epidemiological_week', 'date', 'state', 'city', 'place_type', 'last_available_confirmed', 'new_confirmed',
                   'last_available_deaths', 'new_deaths', 'estimated_population_2019', 'last_available_confirmed_per_100k_inhabitants']
gov_col_names = ['semanaEpi', 'datetime', 'estado', 'municipio', 'tipoTerritorio', 'casosAcumulado', 'casosNovos', 
                 'obitosAcumulado', 'obitosNovos', 'populacaoTCU2019', 'casosNormalizado_100mil_habit']
dados_br_io.rename(columns=dict(zip(br_io_col_names, gov_col_names)), inplace=True)
dados_br_io['municipioEstado'] = np.where(dados_br_io['municipio'].notna(), dados_br_io['municipio']+'-'+dados_br_io['estado'], np.nan)
dados_br_io = dados_br_io[['estado', 'municipio', 'municipioEstado', 'datetime',
        'tipoTerritorio', 'order_for_place', 'populacaoTCU2019', 'city_ibge_code', 'semanaEpi',
        'casosAcumulado','obitosAcumulado', 'casosNovos','obitosNovos', 
        'casosNormalizado_100mil_habit', 'last_available_death_rate',
        'is_last', 'is_repeated']]

dados_br_io['tipoTerritorio'] = np.where(dados_br_io['tipoTerritorio'] == 'state', 'estado', 'municipio')

# %%
print(dados_br_io.columns)
print(dados_novos.columns)
# Out:
# Index(['estado', 'municipio', 'municipioEstado', 'datetime', 'tipoTerritorio',
#        'order_for_place', 'populacaoTCU2019', 'city_ibge_code', 'semanaEpi',
#        'casosAcumulado', 'obitosAcumulado', 'casosNovos', 'obitosNovos',
#        'casosNormalizado_100mil_habit', 'last_available_death_rate', 'is_last',
#        'is_repeated'],
#       dtype='object')
# Index(['regiao', 'estado', 'municipio', 'municipioEstado', 'tipoTerritorio',
#        'datetime', 'coduf', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude',
#        'semanaEpi', 'populacaoTCU2019', 'casosAcumulado', 'obitosAcumulado',
#        'casosNovos', 'obitosNovos', 'contadorDiasCasos', 'contadorObitosCasos',
#        'casosNormalizado_100mil_habit', 'obitosNormalizado_100mil_habit',
#        'casosNormalizado_1milhao_habit', 'obitosNormalizado_1milhao_habit',
#        'Recuperadosnovos', 'emAcompanhamentoNovos'],
#       dtype='object')

# %% [markdown]
# ## Comparativo dados [brasil.io](https://brasil.io/dataset/covid19)

# %%
dados_novos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403667 entries, 0 to 403666
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   regiao                           403667 non-null  object
#  1   estado                           403553 non-null  object
#  2   municipio                        400475 non-null  object
#  3   municipioEstado                  400475 non-null  object
#  4   tipoTerritorio                   403667 non-null  object
#  5   datetime                         403667 non-null  datetime64[ns]
#  6   coduf                            403667 non-null  category
#  7   codmun                           400475 non-null  category
#  8   codRegiaoSaude                   400475 non-null  category
#  9   nomeRegiaoSaude                  400475 non-null  object
#  10  semanaEpi                        403667 non-null  int64
#  11  populacaoTCU2019                 403667 non-null  int32
#  12  casosAcumulado                   403667 non-null  int64
#  13  obitosAcumulado                  403667 non-null  int64
#  14  casosNovos                       403667 non-null  int64
#  15  obitosNovos                      403667 non-null  int64
#  16  contadorDiasCasos                403667 non-null  int64
#  17  contadorObitosCasos              403667 non-null  int32
#  18  casosNormalizado_100mil_habit    403667 non-null  float64
#  19  obitosNormalizado_100mil_habit   403667 non-null  float64
#  20  casosNormalizado_1milhao_habit   403667 non-null  float64
#  21  obitosNormalizado_1milhao_habit  403667 non-null  float64
#  22  Recuperadosnovos                 403667 non-null  int32
#  23  emAcompanhamentoNovos            403667 non-null  int32
# dtypes: category(3), datetime64[ns](1), float64(4), int32(4), int64(6), object(6)
# memory usage: 60.7+ MB

# %%
tipoTerritorio = 'municipio'
col_new_merge = ['datetime', 'municipioEstado', 'casosAcumulado','casosNovos', 'obitosAcumulado', 'obitosNovos']
merge_on = ['datetime', 'municipioEstado']
col_drop = ['regiao', 'municipio', 'semanaEpi', 'populacaoTCU2019','casosNormalizado_100mil_habit', 'obitosNormalizado_100mil_habit','casosNormalizado_1milhao_habit', 'obitosNormalizado_1milhao_habit','contadorDiasCasos', 'contadorObitosCasos']
suffixes = ('_gov', '_br_io')
comp_br_io = merge_compare(dados_novos, dados_br_io, tipoTerritorio, col_new_merge, merge_on, col_drop, suffixes)

coluna_comparacao = ['casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos']
new_cols = diferenca_dados(comp_br_io, suffixes, coluna_comparacao)

comp_br_io[new_cols] = comp_br_io[new_cols].replace({0: np.nan})
# print(comp_gov.columns)
print(comp_br_io.shape)
comp_br_io[new_cols].dropna(thresh=1, axis=0).notna().sum()
# Out:
# (400475, 22)
# casosAcumulado_dif     22737
# casosNovos_dif         31688
# obitosAcumulado_dif     3822
# obitosNovos_dif         5678
# dtype: int64

# %%
municipios = ['Rio de Janeiro-RJ']
drop_cols = ['coduf', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude', 'Recuperadosnovos', 'emAcompanhamentoNovos']
drop_cols_ext = [col for col in comp_br_io.columns for word in ['casosNovos', 'obitosNovos'] if word in col]
drop_cols.extend(drop_cols_ext)
conditions = (comp_br_io['municipioEstado'].isin(municipios)) & ((comp_br_io['casosAcumulado_dif'] != 0) | (comp_br_io['obitosAcumulado_dif'] != 0))
comp_br_io[conditions].drop(drop_cols, axis=1).head(70)
# Out:
#        estado    municipioEstado tipoTerritorio   datetime  \
# 237546     RJ  Rio de Janeiro-RJ      municipio 2020-03-27
# 237547     RJ  Rio de Janeiro-RJ      municipio 2020-03-28
# 237548     RJ  Rio de Janeiro-RJ      municipio 2020-03-29
# 237549     RJ  Rio de Janeiro-RJ      municipio 2020-03-30
# 237550     RJ  Rio de Janeiro-RJ      municipio 2020-03-31
# 237551     RJ  Rio de Janeiro-RJ      municipio 2020-04-01
# 237552     RJ  Rio de Janeiro-RJ      municipio 2020-04-02
# 237553     RJ  Rio de Janeiro-RJ      municipio 2020-04-03
# 237554     RJ  Rio de Janeiro-RJ      municipio 2020-04-04
# 237555     RJ  Rio de Janeiro-RJ      municipio 2020-04-05
# 237556     RJ  Rio de Janeiro-RJ      municipio 2020-04-06
# 237557     RJ  Rio de Janeiro-RJ      municipio 2020-04-07
# 237558     RJ  Rio de Janeiro-RJ      municipio 2020-04-08
# 237559     RJ  Rio de Janeiro-RJ      municipio 2020-04-09
# 237560     RJ  Rio de Janeiro-RJ      municipio 2020-04-10
# 237561     RJ  Rio de Janeiro-RJ      municipio 2020-04-11
# 237562     RJ  Rio de Janeiro-RJ      municipio 2020-04-12
# 237563     RJ  Rio de Janeiro-RJ      municipio 2020-04-13
# 237564     RJ  Rio de Janeiro-RJ      municipio 2020-04-14
# 237565     RJ  Rio de Janeiro-RJ      municipio 2020-04-15
# 237566     RJ  Rio de Janeiro-RJ      municipio 2020-04-16
# 237567     RJ  Rio de Janeiro-RJ      municipio 2020-04-17
# 237568     RJ  Rio de Janeiro-RJ      municipio 2020-04-18
# 237569     RJ  Rio de Janeiro-RJ      municipio 2020-04-19
# 237570     RJ  Rio de Janeiro-RJ      municipio 2020-04-20
# 237571     RJ  Rio de Janeiro-RJ      municipio 2020-04-21
# 237572     RJ  Rio de Janeiro-RJ      municipio 2020-04-22
# 237573     RJ  Rio de Janeiro-RJ      municipio 2020-04-23
# 237574     RJ  Rio de Janeiro-RJ      municipio 2020-04-24
# 237575     RJ  Rio de Janeiro-RJ      municipio 2020-04-25
# 237576     RJ  Rio de Janeiro-RJ      municipio 2020-04-26
# 237577     RJ  Rio de Janeiro-RJ      municipio 2020-04-27
# 237578     RJ  Rio de Janeiro-RJ      municipio 2020-04-28
# 237579     RJ  Rio de Janeiro-RJ      municipio 2020-04-29
# 237580     RJ  Rio de Janeiro-RJ      municipio 2020-04-30
# 237581     RJ  Rio de Janeiro-RJ      municipio 2020-05-01
# 237582     RJ  Rio de Janeiro-RJ      municipio 2020-05-02
# 237583     RJ  Rio de Janeiro-RJ      municipio 2020-05-03
# 237584     RJ  Rio de Janeiro-RJ      municipio 2020-05-04
# 237585     RJ  Rio de Janeiro-RJ      municipio 2020-05-05
# 237586     RJ  Rio de Janeiro-RJ      municipio 2020-05-06
# 237587     RJ  Rio de Janeiro-RJ      municipio 2020-05-07
# 237588     RJ  Rio de Janeiro-RJ      municipio 2020-05-08
# 237589     RJ  Rio de Janeiro-RJ      municipio 2020-05-09
# 237590     RJ  Rio de Janeiro-RJ      municipio 2020-05-10
# 237591     RJ  Rio de Janeiro-RJ      municipio 2020-05-11
# 237592     RJ  Rio de Janeiro-RJ      municipio 2020-05-12
# 237593     RJ  Rio de Janeiro-RJ      municipio 2020-05-13
# 237594     RJ  Rio de Janeiro-RJ      municipio 2020-05-14
# 237595     RJ  Rio de Janeiro-RJ      municipio 2020-05-15
# 237596     RJ  Rio de Janeiro-RJ      municipio 2020-05-16
# 237597     RJ  Rio de Janeiro-RJ      municipio 2020-05-17
# 237598     RJ  Rio de Janeiro-RJ      municipio 2020-05-18
# 237599     RJ  Rio de Janeiro-RJ      municipio 2020-05-19
# 237600     RJ  Rio de Janeiro-RJ      municipio 2020-05-20
# 237601     RJ  Rio de Janeiro-RJ      municipio 2020-05-21
# 237602     RJ  Rio de Janeiro-RJ      municipio 2020-05-22
# 237603     RJ  Rio de Janeiro-RJ      municipio 2020-05-23
# 237604     RJ  Rio de Janeiro-RJ      municipio 2020-05-24
# 237605     RJ  Rio de Janeiro-RJ      municipio 2020-05-25
# 237606     RJ  Rio de Janeiro-RJ      municipio 2020-05-26
# 237607     RJ  Rio de Janeiro-RJ      municipio 2020-05-27
# 237608     RJ  Rio de Janeiro-RJ      municipio 2020-05-28
# 237609     RJ  Rio de Janeiro-RJ      municipio 2020-05-29
# 237610     RJ  Rio de Janeiro-RJ      municipio 2020-05-30
# 237611     RJ  Rio de Janeiro-RJ      municipio 2020-05-31
# 237612     RJ  Rio de Janeiro-RJ      municipio 2020-06-01
# 237613     RJ  Rio de Janeiro-RJ      municipio 2020-06-02
# 237614     RJ  Rio de Janeiro-RJ      municipio 2020-06-03
# 237615     RJ  Rio de Janeiro-RJ      municipio 2020-06-04
#
#         casosAcumulado_gov  obitosAcumulado_gov  casosAcumulado_br_io  \
# 237546                   0                    0                 431.0
# 237547                 489                    9                 489.0
# 237548                 516                   13                 516.0
# 237549                 553                   13                 553.0
# 237550                 586                   18                 586.0
# 237551                 697                   20                 697.0
# 237552                 798                   31                 798.0
# 237553                 867                   36                 867.0
# 237554                 982                   38                 982.0
# 237555                1068                   42                1068.0
# 237556                1110                   47                1110.0
# 237557                1251                   59                1251.0
# 237558                1449                   73                1449.0
# 237559                1633                   82                1633.0
# 237560                1808                   92                1808.0
# 237561                1905                   98                1905.0
# 237562                1996                  106                1996.0
# 237563                2322                  115                2322.0
# 237564                2393                  140                2393.0
# 237565                2519                  167                2519.0
# 237566                2659                  195                2659.0
# 237567                2946                  219                2946.0
# 237568                3059                  237                3059.0
# 237569                3126                  245                3126.0
# 237570                3243                  257                3243.0
# 237571                3587                  283                3587.0
# 237572                3656                  303                3656.0
# 237573                4027                  322                4027.0
# 237574                4091                  347                4091.0
# 237575                4481                  367                4481.0
# 237576                4498                  382                4498.0
# 237577                5261                  404                5261.0
# 237578                5554                  456                5554.0
# 237579                5689                  496                5689.0
# 237580                5903                  535                5903.0
# 237581                6189                  574                6189.0
# 237582                6448                  603                6448.0
# 237583                6750                  631                6750.0
# 237584                7283                  670                7283.0
# 237585                7832                  713                7832.0
# 237586                8577                  764                8577.0
# 237587                9051                  919                9051.0
# 237588                9672                 1002                9672.0
# 237589               10479                 1092               10479.0
# 237590               10520                 1126               10520.0
# 237591               10619                 1172               10619.0
# 237592               10816                 1279               10816.0
# 237593               11026                 1363               11026.0
# 237594               11264                 1509               11264.0
# 237595               11715                 1631               11715.0
# 237596               12295                 1751               12295.0
# 237597               12921                 1841               12921.0
# 237598               13443                 1960               13443.0
# 237599               14531                 2135               14531.0
# 237600               17066                 2249               17066.0
# 237601               18743                 2376               18743.0
# 237602               20161                 2520               20161.0
# 237603               21043                 2702               21043.0
# 237604               21775                 2755               21775.0
# 237605               22466                 2831               22466.0
# 237606               23290                 2978               23290.0
# 237607               24750                 3135               24750.0
# 237608               25974                 3293               25974.0
# 237609               27311                 3430               27311.0
# 237610               28481                 3525               28481.0
# 237611               29157                 3578               29157.0
# 237612               30014                 3671               30014.0
# 237613               31204                 3828               31204.0
# 237614               32951                 4055               32951.0
# 237615               33695                 4231               33695.0
#
#         obitosAcumulado_br_io  casosAcumulado_dif  obitosAcumulado_dif
# 237546                    6.0               431.0                  6.0
# 237547                    9.0                 NaN                  NaN
# 237548                   13.0                 NaN                  NaN
# 237549                   13.0                 NaN                  NaN
# 237550                   18.0                 NaN                  NaN
# 237551                   20.0                 NaN                  NaN
# 237552                   31.0                 NaN                  NaN
# 237553                   36.0                 NaN                  NaN
# 237554                   38.0                 NaN                  NaN
# 237555                   42.0                 NaN                  NaN
# 237556                   47.0                 NaN                  NaN
# 237557                   59.0                 NaN                  NaN
# 237558                   73.0                 NaN                  NaN
# 237559                   82.0                 NaN                  NaN
# 237560                   92.0                 NaN                  NaN
# 237561                   98.0                 NaN                  NaN
# 237562                  106.0                 NaN                  NaN
# 237563                  115.0                 NaN                  NaN
# 237564                  140.0                 NaN                  NaN
# 237565                  167.0                 NaN                  NaN
# 237566                  195.0                 NaN                  NaN
# 237567                  219.0                 NaN                  NaN
# 237568                  237.0                 NaN                  NaN
# 237569                  245.0                 NaN                  NaN
# 237570                  257.0                 NaN                  NaN
# 237571                  283.0                 NaN                  NaN
# 237572                  303.0                 NaN                  NaN
# 237573                  322.0                 NaN                  NaN
# 237574                  347.0                 NaN                  NaN
# 237575                  367.0                 NaN                  NaN
# 237576                  382.0                 NaN                  NaN
# 237577                  405.0                 NaN                  1.0
# 237578                  456.0                 NaN                  NaN
# 237579                  496.0                 NaN                  NaN
# 237580                  535.0                 NaN                  NaN
# 237581                  574.0                 NaN                  NaN
# 237582                  603.0                 NaN                  NaN
# 237583                  631.0                 NaN                  NaN
# 237584                  670.0                 NaN                  NaN
# 237585                  713.0                 NaN                  NaN
# 237586                  764.0                 NaN                  NaN
# 237587                  919.0                 NaN                  NaN
# 237588                 1002.0                 NaN                  NaN
# 237589                 1092.0                 NaN                  NaN
# 237590                 1126.0                 NaN                  NaN
# 237591                 1172.0                 NaN                  NaN
# 237592                 1279.0                 NaN                  NaN
# 237593                 1363.0                 NaN                  NaN
# 237594                 1509.0                 NaN                  NaN
# 237595                 1631.0                 NaN                  NaN
# 237596                 1751.0                 NaN                  NaN
# 237597                 1841.0                 NaN                  NaN
# 237598                 1960.0                 NaN                  NaN
# 237599                 2135.0                 NaN                  NaN
# 237600                 2249.0                 NaN                  NaN
# 237601                 2376.0                 NaN                  NaN
# 237602                 2520.0                 NaN                  NaN
# 237603                 2702.0                 NaN                  NaN
# 237604                 2755.0                 NaN                  NaN
# 237605                 2831.0                 NaN                  NaN
# 237606                 2978.0                 NaN                  NaN
# 237607                 3135.0                 NaN                  NaN
# 237608                 3293.0                 NaN                  NaN
# 237609                 3430.0                 NaN                  NaN
# 237610                 3525.0                 NaN                  NaN
# 237611                 3578.0                 NaN                  NaN
# 237612                 3671.0                 NaN                  NaN
# 237613                 3828.0                 NaN                  NaN
# 237614                 4055.0                 NaN                  NaN
# 237615                 4231.0                 NaN                  NaN

# %%
drop_cols = ['coduf', 'codmun', 'codRegiaoSaude', 'nomeRegiaoSaude', 'Recuperadosnovos', 'emAcompanhamentoNovos']
drop_cols_ext = [col for col in comp_br_io.columns for word in ['casosNovos', 'obitosNovos'] if word in col]
drop_cols.extend(drop_cols_ext)
grouped_comp_br_io = comp_br_io.drop(drop_cols, axis=1).groupby(['casosAcumulado_dif', 'obitosAcumulado_dif', 'municipioEstado'], as_index=False).sum().sort_values(by=['casosAcumulado_dif'], ascending=False)
diff_freq = grouped_comp_br_io.head(100)['municipioEstado'].value_counts()
print("100 Maiores diferenças de casos entre gov_br e br_io")
print(diff_freq.loc[diff_freq>1])
grouped_comp_br_io.head(10)
# Out:
# 100 Maiores diferenças de casos entre gov_br e br_io
# Brasília-DF          36
# Belém-PA             15
# São Luís-MA          13
# Natal-RN              7
# Recife-PE             4
# Fortaleza-CE          3
# Porto Velho-RO        3
# São Paulo-SP          2
# Rio de Janeiro-RJ     2
# Teresina-PI           2
# Name: municipioEstado, dtype: int64
#       casosAcumulado_dif  obitosAcumulado_dif    municipioEstado  \
# 2562              4413.0                136.0      Rio Branco-AC
# 2561              3056.0                 34.0        Brasília-DF
# 2560              2920.0                 32.0        Brasília-DF
# 2559              2401.0                 31.0        Brasília-DF
# 2558              2285.0                 28.0        Brasília-DF
# 2557              2197.0                 28.0        Brasília-DF
# 2556              2139.0                 26.0        Brasília-DF
# 2555              2104.0                104.0  Rio de Janeiro-RJ
# 2554              2043.0                 24.0        Brasília-DF
# 2553              1890.0                 24.0        Brasília-DF
#
#       casosAcumulado_gov  obitosAcumulado_gov  casosAcumulado_br_io  \
# 2562                4413                  136                   0.0
# 2561               27140                  365               24084.0
# 2560               25380                  348               22460.0
# 2559               23684                  319               21283.0
# 2558               22871                  304               20586.0
# 2557               21959                  293               19762.0
# 2556               21396                  282               19257.0
# 2555               45978                 5343               43874.0
# 2554               20507                  274               18464.0
# 2553               19433                  256               17543.0
#
#       obitosAcumulado_br_io
# 2562                    0.0
# 2561                  331.0
# 2560                  316.0
# 2559                  288.0
# 2558                  276.0
# 2557                  265.0
# 2556                  256.0
# 2555                 5239.0
# 2554                  250.0
# 2553                  232.0

# %% [markdown]
# ## Plot - Casos Acumulados (gov.br vs br.io)

# %%
# comp_gov[comp_gov['municipioEstado'].isin(municipios)][['datetime', 'municipioEstado','casosAcumulado_gov', 'casosAcumulado_br_io']].head()

municipios = ['Brasília-DF', 'Araguaína-TO']
municipios2 = ['Salvador-BA', 'Recife-PE']
groupby_var = ['datetime', 'municipioEstado']
column_list = ['casosAcumulado_gov', 'casosAcumulado_br_io']
xaxis_datetime_bool = True

fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

plot_data_completo(dataframe = comp_br_io, column_string = 'municipioEstado', 
            rows_list = municipios, 
            groupby_list = groupby_var,
            column_list = column_list, 
            title_string = "", 
            legend_bool = True, logy_bool = True, figsize_x = 25, figsize_y = 10, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 12,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

# %% [markdown]
# ## Plot - Casos Acumulados (gov.br vs br.io) - Brasília após 4/15

# %%
# comp_gov[comp_gov['municipioEstado'].isin(municipios)][['datetime', 'municipioEstado','casosAcumulado_gov', 'casosAcumulado_br_io']].head()

municipios = ['Brasília-DF']
municipios2 = ['Salvador-BA', 'Recife-PE', 'Araguaína-TO']
groupby_var = ['datetime', 'municipioEstado']
column_list = ['casosAcumulado_gov', 'casosAcumulado_br_io']
xaxis_datetime_bool = True

fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

plot_data_completo(dataframe = comp_br_io[(comp_br_io['datetime']>'2020-04-15')], column_string = 'municipioEstado', 
            rows_list = municipios, 
            groupby_list = groupby_var,
            column_list = column_list, 
            title_string = "", 
            legend_bool = True, logy_bool = False, figsize_x = 25, figsize_y = 10, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 12,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

# %% [markdown]
# ## Plot - Óbitos Acumulados e Acumulado Normalizados

# %%
municipios = ['Rio de Janeiro-RJ', 'Manaus-AM', 'Florianópolis-SC', 'Belém-PA', 'Fortaleza-CE', 'São Luís-MA']
groupby_var = ['datetime', 'municipioEstado']
column_list = ['obitosAcumulado']
xaxis_datetime_bool = True

fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

plot_data_completo(dataframe = dados_novos, column_string = 'municipioEstado', 
            rows_list = municipios, 
            groupby_list = groupby_var,
            column_list = column_list, 
            title_string = "", 
            legend_bool = True, logy_bool = False, figsize_x = 25, figsize_y = 10, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 12,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

# %%
municipios = ['Rio de Janeiro-RJ', 'Manaus-AM', 'Florianópolis-SC', 'Belém-PA', 'Fortaleza-CE', 'São Luís-MA']
groupby_var = ['datetime', 'municipioEstado']
column_list = ['obitosNormalizado_1milhao_habit']
xaxis_datetime_bool = True

fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

plot_data_completo(dataframe = dados_novos, column_string = 'municipioEstado', 
            rows_list = municipios, 
            groupby_list = groupby_var,
            column_list = column_list, 
            title_string = "", 
            legend_bool = True, logy_bool = True, figsize_x = 25, figsize_y = 10, 
            bbox_anchor_x = 1.1, bbox_anchor_y = 0.5, labels_fontsize = 12,
            xaxis_datetime_bool = xaxis_datetime_bool, xaxis_title_string = '', yaxis_title_string = '', axes=axes)

# %% [markdown]
# ## Plot Média Móvel - Óbitos Novos

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

dataframe = dados_novos
column_string = 'municipioEstado'
municipios = ['Rio de Janeiro-RJ', 'Manaus-AM', 'Florianópolis-SC', 'Belém-PA', 'Fortaleza-CE', 'São Luís-MA']
rows_list = municipios
groupby_string = 'datetime'
# groupby_var = ['datetime', 'municipioEstado']
# groupby_list=groupby_var
# column_list = ['obitosNovos_gov']
# column_list = ['municipioEstado', 'datetime','obitosNovos_gov', 'obitosNovos_br_io']
column_list = ['municipioEstado', 'datetime','obitosNovos']
rolling_type='mean'
rolling_days=7
xaxis_datetime_bool=True
(figsize_x, figsize_y, logy_bool, title_string, axes) = (30,12, False, "", axes)
legend_bool=True


for row in rows_list:
    if rolling_type == 'sum':
        dataframe[dataframe[column_string]==row][column_list].sort_values(by=groupby_string).groupby(groupby_string).sum().rolling(rolling_days).sum() \
            .plot(figsize=(figsize_x, figsize_y), legend=False, logy=logy_bool, title=title_string, ax=axes)
        
    if rolling_type == 'mean':
        dataframe[dataframe[column_string]==row][column_list].sort_values(by=groupby_string).groupby(groupby_string).mean().rolling(rolling_days).mean() \
            .plot(figsize=(figsize_x, figsize_y), legend=False, logy=logy_bool, title=title_string, ax=axes)
        
# (bbox_anchor_x, bbox_anchor_y, labels_fontsize, legend_bool,xaxis_datetime_bool, xaxis_title_string, yaxis_title_string)
caracteristicas_plot(1.0, 0.5, 12, False, xaxis_datetime_bool, "Data", "")
plt.gcf().legend(municipios)
